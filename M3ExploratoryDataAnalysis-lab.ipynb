# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
#df['ConvertedComp'].to_frame()

plt.hist(df['ConvertedComp'], bins=200)
# Out:
# (array([9.670e+02, 1.087e+03, 8.490e+02, 8.540e+02, 8.670e+02, 8.310e+02,
#         7.870e+02, 6.600e+02, 5.570e+02, 4.670e+02, 3.980e+02, 2.900e+02,
#         2.680e+02, 2.110e+02, 1.580e+02, 1.670e+02, 1.010e+02, 5.600e+01,
#         5.400e+01, 3.000e+01, 4.700e+01, 2.100e+01, 1.800e+01, 2.000e+01,
#         1.000e+01, 2.300e+01, 6.000e+00, 1.000e+01, 5.000e+00, 2.000e+00,
#         1.900e+01, 7.000e+00, 6.000e+00, 2.000e+00, 7.000e+00, 5.000e+00,
#         6.000e+00, 1.100e+01, 7.000e+00, 6.000e+00, 9.000e+00, 1.000e+01,
#         7.000e+00, 4.000e+00, 2.000e+00, 1.000e+01, 3.000e+00, 4.000e+00,
#         1.200e+01, 4.000e+00, 5.000e+00, 1.000e+00, 3.000e+00, 6.000e+00,
#         1.100e+01, 2.000e+00, 4.000e+00, 7.000e+00, 3.000e+00, 8.000e+00,
#         9.000e+00, 8.000e+00, 1.100e+01, 4.000e+00, 6.000e+00, 1.400e+01,
#         1.000e+00, 2.000e+00, 9.000e+00, 5.000e+00, 1.000e+01, 3.000e+00,
#         6.000e+00, 2.000e+00, 3.000e+00, 1.100e+01, 4.000e+00, 1.000e+00,
# ...

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

plt.hist(x=df['ConvertedComp'], bins=25)
# Out:
# (array([6.902e+03, 2.516e+03, 3.470e+02, 8.200e+01, 5.000e+01, 4.900e+01,
#         4.400e+01, 5.400e+01, 5.000e+01, 4.300e+01, 4.600e+01, 2.400e+01,
#         1.360e+02, 1.200e+01, 1.200e+01, 1.600e+01, 1.500e+01, 4.000e+00,
#         9.000e+00, 5.000e+00, 5.000e+00, 1.000e+01, 7.000e+00, 5.000e+00,
#         1.390e+02]),
#  array([      0.,   80000.,  160000.,  240000.,  320000.,  400000.,
#          480000.,  560000.,  640000.,  720000.,  800000.,  880000.,
#          960000., 1040000., 1120000., 1200000., 1280000., 1360000.,
#         1440000., 1520000., 1600000., 1680000., 1760000., 1840000.,
#         1920000., 2000000.]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df['Gender'].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
#df_woman = df[df['Gender']=='Woman']
df_woman['ConvertedComp'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
plt.hist(df['Age'], bins=25)
# Out:
# (array([1.160e+02, 7.190e+02, 1.997e+03, 2.928e+03, 1.671e+03, 1.271e+03,
#         1.099e+03, 4.850e+02, 2.800e+02, 2.640e+02, 1.270e+02, 7.100e+01,
#         5.000e+01, 1.700e+01, 9.000e+00, 3.000e+00, 3.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00]),
#  array([16.  , 19.32, 22.64, 25.96, 29.28, 32.6 , 35.92, 39.24, 42.56,
#         45.88, 49.2 , 52.52, 55.84, 59.16, 62.48, 65.8 , 69.12, 72.44,
#         75.76, 79.08, 82.4 , 85.72, 89.04, 92.36, 95.68, 99.  ]),
#  <BarContainer object of 25 artists>)

# %%
df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here

df['ConvertedComp'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
#print(df['ConvertedComp'].max())
#print(df['ConvertedComp'].min())
# Out:
# 2000000.0
# 0.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here

up_q = 1.000000e+05
low_q = 2.686800e+04
outlier = (1.000000e+05 - 2.686800e+04)*1.5
outlier_count=0

for index, row in df.iterrows():
    if row['ConvertedComp'] > (up_q + outlier):
        outlier_count += 1
    if row['ConvertedComp'] < (low_q - outlier):
        outlier_count += 1

outlier_count
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
#df_ex_outliers = df.drop(df[df['ConvertedComp'] > (up_q + outlier)].index)
#df_ex_outliers = df_ex_outliers.drop(df[df['ConvertedComp'] < (low_q - outlier)].index)
df_ex_outliers['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr()
df_corr = df.groupby('Age')['ConvertedComp'].mean()
df_corr

plt.plot(x,y)
# Out:
# Age
# 16.0     15504.000000
# 17.0     57762.750000
# 18.0     31808.347826
# 19.0     52088.450704
# 20.0     57555.230000
#             ...
# 67.0    104000.000000
# 69.0    165000.000000
# 71.0    175000.000000
# 72.0     96000.000000
# 99.0    125000.000000
# Name: ConvertedComp, Length: 63, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
